# %%
name="Suja"
age=19
OGPA=8.5
placed=False
print("Student Name:",name)
print("Age:",age)
print("OGPA:",OGPA)
print("Placed:",placed)
print(type(name))
print(type(age))
print(type(OGPA))
print(type(placed))
# Out:
# Student Name: Suja
# Age: 19
# OGPA: 8.5
# Placed: False
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
